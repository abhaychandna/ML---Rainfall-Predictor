# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("rainfall in india 1901-2015.csv")

# %%
df = pd.read_csv("rainfall in india 1901-2015.csv")
df.isnull().sum()
#df = df[df.isnull() == False](axis = 1)
df = df.dropna()

# %%
df['SUBDIVISION'].value_counts()
# Out:
# UTTARAKHAND                           115
# ORISSA                                115
# GUJARAT REGION                        115
# ASSAM & MEGHALAYA                     115
# JHARKHAND                             115
# CHHATTISGARH                          115
# COASTAL ANDHRA PRADESH                115
# SAURASHTRA & KUTCH                    115
# NORTH INTERIOR KARNATAKA              115
# MATATHWADA                            115
# VIDARBHA                              115
# GANGETIC WEST BENGAL                  115
# EAST RAJASTHAN                        115
# NAGA MANI MIZO TRIPURA                115
# EAST MADHYA PRADESH                   115
# TELANGANA                             115
# EAST UTTAR PRADESH                    115
# SOUTH INTERIOR KARNATAKA              115
# WEST RAJASTHAN                        115
# HARYANA DELHI & CHANDIGARH            115
# WEST UTTAR PRADESH                    115
# MADHYA MAHARASHTRA                    115
# ...

# %%
df.groupby('SUBDIVISION').size()
# Out:
# SUBDIVISION
# ANDAMAN & NICOBAR ISLANDS             104
# ARUNACHAL PRADESH                      91
# ASSAM & MEGHALAYA                     115
# BIHAR                                 115
# CHHATTISGARH                          115
# COASTAL ANDHRA PRADESH                115
# COASTAL KARNATAKA                     114
# EAST MADHYA PRADESH                   115
# EAST RAJASTHAN                        115
# EAST UTTAR PRADESH                    115
# GANGETIC WEST BENGAL                  115
# GUJARAT REGION                        115
# HARYANA DELHI & CHANDIGARH            115
# HIMACHAL PRADESH                      115
# JAMMU & KASHMIR                       114
# JHARKHAND                             115
# KERALA                                115
# KONKAN & GOA                          115
# LAKSHADWEEP                           103
# MADHYA MAHARASHTRA                    115
# MATATHWADA                            115
# NAGA MANI MIZO TRIPURA                115
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr = df.corr()

# %%
plt.figure(figsize = (100,25))
#sns.set(font_scale = 3)
heatmap = sns.heatmap(corr,cmap = "YlGnBu",annot = True)
plt.show()

# %%
sns.set(font_scale = 1)
sns.scatterplot(x=df2.YEAR,y=df2.ANNUAL)

# %%
df['ANNUAL'].plot(kind = 'box')

# %%
#Histogram of all states
df2.ANNUAL.hist(bins=100)

# %%
sns.violinplot(data = df.ANNUAL)

# %%
#df.drop(label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-7c34a5a4d627> in <module>
# ----> 1 df.drop(label)
#
# NameError: name 'label' is not defined

# %%
df2 = df[df.SUBDIVISION == 'PUNJAB']
df2
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL    AUG  \
# 1472      PUNJAB  1901  55.7  50.1  25.2   2.1  25.2   10.4  178.2  145.0
# 1473      PUNJAB  1902   0.0   0.8   9.9  10.9  29.6   49.9  125.6   94.9
# 1474      PUNJAB  1903  29.5   0.5  45.0   1.3   9.2    5.2  212.2  119.1
# 1475      PUNJAB  1904  24.2   1.7  87.8   1.2  13.8   22.0   59.9  124.0
# 1476      PUNJAB  1905  53.0  40.3  24.3   0.5   2.2   19.2  122.6   50.3
# ...          ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 1582      PUNJAB  2011   3.5  35.6   8.2  17.8  18.9  162.9  120.9  193.5
# 1583      PUNJAB  2012  62.6   3.2   1.9  31.1   1.6   11.9  120.2  135.1
# 1584      PUNJAB  2013   9.3  50.1  11.6   3.4   3.6  120.3  117.9  217.1
# 1585      PUNJAB  2014  21.8  20.1  30.3  24.5  20.8   20.6   76.3   41.9
# 1586      PUNJAB  2015  17.7  31.3  68.5  29.8  16.7   48.3  130.2   88.6
#
#         SEP   OCT  NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df2[['YEAR']],df2[['ANNUAL']],random_state = 42)
X_train
# Out:
#       YEAR
# 1580  2009
# 1550  1979
# 1487  1916
# 1502  1931
# 1555  1984
# ...    ...
# 1578  2007
# 1486  1915
# 1564  1993
# 1523  1952
# 1574  2003
#
# [86 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
#x = df2.iloc[:,2:4]

x = df2[['ANNUAL']]

x = np.array(x.values)
#x.reshape(-1,115)



x = scaler.fit_transform(x)
x
#x = np.array(x)
#x.values.reshape(x.values , (-1,1))
#x = x.values
#print(x.shape)
#x.reshape(1, -1)
#print(x)
#print(x.shape)
#df2.loc[:,2:4]= scaler.fit_transform(x)
#df2
# Out:
# array([[-0.43060237],
#        [-1.2022179 ],
#        [-0.13855665],
#        [-0.8732822 ],
#        [-0.97903349],
#        [ 0.5162406 ],
#        [-0.02665702],
#        [ 0.90297061],
#        [ 1.55284919],
#        [ 0.13996274],
#        [-0.54065749],
#        [-0.3512889 ],
#        [-0.19881029],
#        [ 1.23498048],
#        [-1.05650246],
#        [-0.03157569],
#        [ 3.27807086],
#        [-1.56128043],
#        [-0.26828643],
#        [-1.29382803],
#        [-1.37191183],
#        [-0.49147084],
#        [ 0.88759979],
#        [-0.01681969],
#        [ 0.22173555],
#        [ 0.08462777],
#        [-0.69190643],
#        [-0.96181816],
#        [-1.04850963],
#        [-0.22340361],
#        [-0.03034602],
#        [-0.63472695],
#        [ 1.64199999],
#        [-1.01038998],
#        [ 0.02867795],
#        [ 0.20206089],
#        [-0.13794181],
#        [-0.99993781],
#        [-1.16717241],
#        [-0.37711189],
#        [-0.53635366],
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import * 
pred = lr.predict(X_test)
print("MSE = ", mean_squared_error(pred,y_test))
print ("ROOT = ", np.sqrt(mean_squared_error(pred,y_test)))
print("Absolute Eror = ",mean_absolute_error(pred,y_test))
print("r2 Score = ",r2_score(pred,y_test))
# Out:
# MSE =  14832.339242289128
# ROOT =  121.78809154547552
# Absolute Eror =  102.56155017545733
# r2 Score =  -82.16023476243002

# %%
plt.scatter(pred,y_test)
plt.show()
